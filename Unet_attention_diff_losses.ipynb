# %% [markdown]
# <a href="https://colab.research.google.com/github/varJATIN/Amazon-Food-Reviews-Summarization/blob/master/Unet_attention_diff_losses.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys
import random

import numpy as np
import cv2
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras

## Seeding 
seed = 2019
random.seed = seed
np.random.seed = seed
tf.seed = seed

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def down_block(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(x)
    c=tf.keras.layers.BatchNormalization()(c)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    c=tf.keras.layers.BatchNormalization()(c)
    p = keras.layers.MaxPool2D((2, 2), (2, 2))(c)
    return c, p

def atten(x,g,F_x,F_g,F_int,kernel_size=(3,3), padding="same", strides=1):
    # upsample lower decoder filters
    us = keras.layers.UpSampling2D((2, 2))(g)
    gate = keras.layers.Conv2D(F_g, kernel_size, padding=padding, strides=strides, activation="relu")(us)
    gate=tf.keras.layers.BatchNormalization()(gate)
    
    # convolve the upsampled decoder filter for F_int filters
    W_g=keras.layers.Conv2D(F_int, kernel_size=1, padding=padding, strides=strides)(gate)
    W_g=tf.keras.layers.BatchNormalization()(W_g)
    
    # convolve encoder output for F_int filters
    W_x=keras.layers.Conv2D(F_int, kernel_size=1, padding=padding, strides=strides)(x)
    W_x=tf.keras.layers.BatchNormalization()(W_x)
    
    # convolve to one attention filter
    psi=tf.keras.activations.relu(W_x+W_g, alpha=0.0, max_value=None, threshold=0)
    psi=keras.layers.Conv2D(1, kernel_size=1, padding=padding, strides=strides)(psi)
    psi=tf.keras.activations.sigmoid(tf.keras.layers.BatchNormalization()(psi))
    
    # return the filtered encoder output for concat
    return x*psi

def up_block(x, skip, filters, kernel_size=(3, 3), padding="same", strides=1):
    us = keras.layers.UpSampling2D((2, 2))(x)
    us = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(us)
    us = tf.keras.layers.BatchNormalization()(us)
    # here skip is from encoder and x if from dec previous layer 
    filtered_skip=atten(skip,x,filters,filters,filters/2)
    #concat filtrd skip and upsampled us
    concat = keras.layers.Concatenate()([us, filtered_skip])
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(concat)
    c=tf.keras.layers.BatchNormalization()(c)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    c=tf.keras.layers.BatchNormalization()(c)
    return c

def bottleneck(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(x)
    c=tf.keras.layers.BatchNormalization()(c)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    c=tf.keras.layers.BatchNormalization()(c) 
    return c

# %%
def UNet():
    #f = [16, 32, 64, 128, 256]
    f = [3, 6, 12, 24, 48]
    
    inputs = keras.layers.Input((image_size, image_size, 3))
    
    p0 = inputs
    c1, p1 = down_block(p0, f[0]) #128 -> 64
    c2, p2 = down_block(p1, f[1]) #64 -> 32
    c3, p3 = down_block(p2, f[2]) #32 -> 16
    c4, p4 = down_block(p3, f[3]) #16->8
    
    bn = bottleneck(p4, f[4])#8*8*48
    
    u1 = up_block(bn, c4, f[3]) #8 - > 16
    u2 = up_block(u1, c3, f[2]) #16 -> 32
    u3 = up_block(u2, c2, f[1]) #32 -> 64
    u4 = up_block(u3, c1, f[0]) #64 -> 128
    
    outputs = keras.layers.Conv2D(1, (1, 1), padding="same", activation="sigmoid")(u4)
    model = keras.models.Model(inputs, outputs)
    return model

# %%
from sklearn.utils import shuffle
from matplotlib.pyplot import imread
from cv2 import resize
import matplotlib.pyplot as plt
import cv2

# %%
# data
data_location =  "/content/drive/My Drive/Eye data segmentaion/diaretdb1_v_1_1/diaretdb1_v_1_1/resources/images/ddb1_fundusimages"
train_data = []  # create an empty list
for dirName, subdirList, fileList in sorted(os.walk(data_location)):
    print(dirName,subdirList,fileList)
    for filename in sorted(fileList):
        if ".png" in filename.lower() :
            train_data.append(os.path.join(dirName,filename))
# Out:
# /content/drive/My Drive/Eye data segmentaion/diaretdb1_v_1_1/diaretdb1_v_1_1/resources/images/ddb1_fundusimages [] ['image005.png', 'image003.png', 'image002.png', 'image004.png', 'image001.png', 'image008.png', 'image010.png', 'image011.png', 'image013.png', 'image007.png', 'image009.png', 'image006.png', 'image012.png', 'image016.png', 'image019.png', 'image015.png', 'image020.png', 'image014.png', 'image017.png', 'image021.png', 'image018.png', 'image025.png', 'image023.png', 'image024.png', 'image028.png', 'image022.png', 'image027.png', 'image026.png', 'image029.png', 'image030.png', 'image036.png', 'image034.png', 'image035.png', 'image040.png', 'image033.png', 'image032.png', 'image037.png', 'image031.png', 'image038.png', 'image041.png', 'image039.png', 'image054.png', 'image056.png', 'image045.png', 'image053.png', 'image046.png', 'image051.png', 'image048.png', 'image043.png', 'image050.png', 'image057.png', 'image042.png', 'image044.png', 'image055.png', 'image047.png', 'image052.png', 'image049.png', 'image063.png', 'image059.png', 'image061.png', 'image060.png', 'image062.png', 'image064.png', 'image058.png', 'image065.png', 'image067.png', 'image071.png', 'image072.png', 'image068.png', 'image070.png', 'image066.png', 'image069.png', 'image084.png', 'image081.png', 'image073.png', 'image082.png', 'image080.png', 'image076.png', 'image079.png', 'image077.png', 'image083.png', 'image075.png', 'image078.png', 'image074.png', 'image086.png', 'image088.png', 'image089.png', 'image085.png', 'image087.png']

# %%
data_location = "/content/drive/My Drive/Eye data segmentaion/diaretdb1_v_1_1/diaretdb1_v_1_1/resources/images/ddb1_groundtruth/hardexudates"
train_data_gt = []  # create an empty list
for dirName, subdirList, fileList in sorted(os.walk(data_location)):
    for filename in sorted(fileList):
        if ".png" in filename.lower() :
            train_data_gt.append(os.path.join(dirName,filename))

# %%
mask=[]
data_location = "/content/drive/My Drive/Eye data segmentaion/diaretdb1_v_1_1/diaretdb1_v_1_1/resources/images/ddb1_fundusmask"
for dirName, subdirList, fileList in sorted(os.walk(data_location)):
    for filename in fileList:
        if ".tif" in filename.lower() :
            mask.append(os.path.join(dirName,filename))

# %%
print(imread(mask[0]).shape)
img = cv2.cvtColor(imread(mask[0]), cv2.COLOR_BGRA2BGR)
print("Reduced channels",img.shape)
print("BGR fundus_mask")
plt.imshow(img)
plt.show()
#print("inverted fundus_mask")
dst=255-img
"""plt.imshow(dst)
plt.show()"""
# Out:
# (1152, 1500, 4)
# Reduced channels (1152, 1500, 3)
# BGR fundus_mask
# 'plt.imshow(dst)\nplt.show()'

# %%
print("plot raw grountruth")
#train_img_gt and train_img is given in range 0-1
plt.imshow(255*imread(train_data_gt[2]),cmap='gray')
plt.show()

print("plot grayscale mask")
#img is in range 0-255
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_image,cmap='gray')
plt.show()
print("inverted grayscale fundus_mask")
plt.imshow(255-gray_image,cmap='gray')
plt.show()

print("plot input image - fundus_mask  ")
print(dst.dtype,imread(train_data[2]).dtype)
plt.imshow(((imread(train_data[2])*255).astype(int))-dst,cmap='gray')
plt.show()
"""
print("plot input image*255  ")
print(dst.dtype,imread(train_data[2]).dtype)
plt.imshow(((imread(train_data[2])*255).astype(int)))
plt.show()"""


#reduce img to 1d
print("plot  groundtruth - grayscale fundus_mask ")
plt.imshow((imread(train_data_gt[2])*255).astype(int)-gray_image+255,cmap='gray')
plt.show()
#nothing happened
#now invert the output mask would work as we are getting 0 class identified prominantly in the generated mask 
# we are doing 2 class clasification
print("inverted groundtruth ")
plt.imshow(255-imread(train_data_gt[2]),cmap='gray')
plt.show()
# Out:
# plot raw grountruth
# plot grayscale mask
# inverted grayscale fundus_mask
# plot input image - fundus_mask
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# uint8 float32
# plot  groundtruth - grayscale fundus_mask
# inverted groundtruth

# %%
"""train_images = np.zeros(shape=(89,512,512,3))
train_labels = np.zeros(shape=(89,512,512,1))
for file_index in range(len(train_data)):
    train_images[file_index,:,:]   = resize(imread(train_data[file_index]),(512,512))
    train_labels[file_index,:,:]   = np.expand_dims(resize(imread(train_data_gt[file_index]),(512,512)),axis=2)
    #train_images[k+1,:,:]   = resize(np.flip(imread(train_data[file_index]),axis=1),(512,512))
    #train_labels[k+1,:,:]   = np.expand_dims(resize(np.flip(imread(train_data_gt[file_index]),axis=1),(512,512)),axis=2)
    mask = train_labels[file_index,:,:]>0.5
    train_labels[file_index,:,:][mask] =1.00
train_images = (train_images)# - train_images.min()) / (train_images.max() - train_images.min())
train_labels = (train_labels)# - train_labels.min()) / (train_labels.max() - train_labels.min())
print(train_images.shape)
print(train_labels.shape)
num_epoch = 100

train_batch = train_images[:38*2]
train_label = train_labels[:38*2]
test_batch = train_images[75:89]
test_label = train_labels[75:89]

print(train_batch.shape)
print(train_label.shape)
print(test_batch.shape)
print(test_label.shape)"""
# discarded as most of the imags has not grund truth i.e. no hard ex
# Out:
# 'train_images = np.zeros(shape=(89,512,512,3))\ntrain_labels = np.zeros(shape=(89,512,512,1))\nfor file_index in range(len(train_data)):\n    train_images[file_index,:,:]   = resize(imread(train_data[file_index]),(512,512))\n    train_labels[file_index,:,:]   = np.expand_dims(resize(imread(train_data_gt[file_index]),(512,512)),axis=2)\n    #train_images[k+1,:,:]   = resize(np.flip(imread(train_data[file_index]),axis=1),(512,512))\n    #train_labels[k+1,:,:]   = np.expand_dims(resize(np.flip(imread(train_data_gt[file_index]),axis=1),(512,512)),axis=2)\n    mask = train_labels[file_index,:,:]>0.5\n    train_labels[file_index,:,:][mask] =1.00\ntrain_images = (train_images)# - train_images.min()) / (train_images.max() - train_images.min())\ntrain_labels = (train_labels)# - train_labels.min()) / (train_labels.max() - train_labels.min())\nprint(train_images.shape)\nprint(train_labels.shape)\nnum_epoch = 100\n\ntrain_batch = train_images[:38*2]\ntrain_label = train_labels[:38*2]\ntest_batch = train_images[75:89]\ntest_label = train_labels[75:89]\n\nprint(train_batch.shape)\nprint(train_label.shape)\nprint(test_batch.shape)\nprint(test_label.shape)'

# %%
hard_ex=[]
for i in range(1,28):
  hard_ex.append(i)
x=[35,38,44,53,54,66,67,71,84,85,86]
for i in x:
  hard_ex.append(i)
print("{} out of 89 has hard executes".format(len(hard_ex)))
# Out:
# 38 out of 89 has hard executes

# %%
train_images = np.zeros(shape=(len(hard_ex)*2,512,512,3))
train_labels = np.zeros(shape=(len(hard_ex)*2,512,512,1))
k=0
for file_index in range(len(train_data)):
    if file_index+1 in hard_ex:
      train_images[k,:,:]   = resize(imread(train_data[file_index]),(512,512))
      train_labels[k,:,:]   = np.expand_dims(resize(imread(train_data_gt[file_index]),(512,512)),axis=2)
      train_images[k+1,:,:]   = resize(np.flip(imread(train_data[file_index]),axis=1),(512,512))
      train_labels[k+1,:,:]   = np.expand_dims(resize(np.flip(imread(train_data_gt[file_index]),axis=1),(512,512)),axis=2)
      mask = train_labels[k,:,:]>0.4
      train_labels[k,:,:][mask] =1.0
      train_labels[k,:,:][~mask] =0.0
      mask = train_labels[k+1,:,:]>0.4
      train_labels[k+1,:,:][mask] =1.0
      train_labels[k+1,:,:][~mask] =0.0
      k+=2
train_images = (train_images)# - train_images.min()) / (train_images.max() - train_images.min())
train_labels = (train_labels)# - train_labels.min()) / (train_labels.max() - train_labels.min())
print(train_images.shape)
print(train_labels.shape)
# Out:
# (76, 512, 512, 3)
# (76, 512, 512, 1)

# %%
train_batch = train_images[:38*2]
train_label = train_labels[:38*2]
test_batch = train_images[36*2:38*2]
test_label = train_labels[36*2:38*2]

# %%
from keras import backend as K
def dice_loss(y_true, y_pred, smooth=1):
  intersection = K.sum(y_true * y_pred, axis=[1,2,3])
  union = K.sum(y_true, axis=[1,2,3]) + K.sum(y_pred, axis=[1,2,3])
  dice = K.mean((2. * intersection + smooth)/(union + smooth), axis=0)
  return 1-dice
def trv_loss(y_true, y_pred, smooth=1):
  intersection = K.sum(y_true * y_pred, axis=[1,2,3])
  union = K.sum(y_true*y_pred, axis=[1,2,3]) + 0.5*K.sum(y_pred*(tf.clip_by_value(1-y_true,0,1)), axis=[1,2,3])+0.5*K.sum(tf.clip_by_value(1-y_pred,0,1)*y_true, axis=[1,2,3])
  dice = K.mean((2. * intersection + smooth)/(union + smooth), axis=0)
  return (1-dice)**1

# %%
seed = 2
random.seed = seed
np.random.seed = seed
tf.seed = seed
tf.random.set_seed(2)
image_size = 512

#set hyperparameters
epochs = 30
batch_size = 2

#define lossed
losses=['trvesky','dice','mse']
models=[]
history=[]
for loss in losses:
  model = UNet()
  opt=keras.optimizers.Adam(learning_rate=0.001)
  if loss=='mse':
    model.compile(optimizer=opt, loss="mse", metrics=[tf.keras.metrics.MeanIoU(num_classes=2)])
  elif loss=='dice':
    model.compile(optimizer=opt, loss=dice_loss, metrics=[tf.keras.metrics.AUC(),tf.keras.metrics.MeanIoU(num_classes=2)])    
  elif loss=='trvesky':
    model.compile(optimizer=opt, loss=trv_loss, metrics=[tf.keras.metrics.AUC(),tf.keras.metrics.MeanIoU(num_classes=2)])
  
  #train model
  print("{}_used for training model".format(loss))
  hist=model.fit(x = train_batch, y = train_label, batch_size = 2, epochs = 30,verbose=1,validation_split=2/76,shuffle=True)
  models.append(model)
  history.append(hist)
  #model.summary()
# Out:
# trvesky_used for training model
# Epoch 1/30
# 37/37 [==============================] - 6s 154ms/step - loss: 0.7400 - auc_8: 0.6989 - mean_io_u_8: 0.4699 - val_loss: 0.9968 - val_auc_8: 0.7671 - val_mean_io_u_8: 0.4996
# Epoch 2/30
# 37/37 [==============================] - 4s 103ms/step - loss: 0.6807 - auc_8: 0.7505 - mean_io_u_8: 0.4699 - val_loss: 0.9967 - val_auc_8: 0.7472 - val_mean_io_u_8: 0.4996
# Epoch 3/30
# 37/37 [==============================] - 4s 103ms/step - loss: 0.6395 - auc_8: 0.8503 - mean_io_u_8: 0.4699 - val_loss: 0.9968 - val_auc_8: 0.7538 - val_mean_io_u_8: 0.4996
# Epoch 4/30
# 37/37 [==============================] - 4s 103ms/step - loss: 0.5537 - auc_8: 0.8671 - mean_io_u_8: 0.4699 - val_loss: 0.9969 - val_auc_8: 0.4953 - val_mean_io_u_8: 0.4996
# Epoch 5/30
# 37/37 [==============================] - 4s 104ms/step - loss: 0.4824 - auc_8: 0.8906 - mean_io_u_8: 0.4699 - val_loss: 0.9965 - val_auc_8: 0.4452 - val_mean_io_u_8: 0.4996
# Epoch 6/30
# 37/37 [==============================] - 4s 104ms/step - loss: 0.4322 - auc_8: 0.8740 - mean_io_u_8: 0.4699 - val_loss: 0.9968 - val_auc_8: 0.6147 - val_mean_io_u_8: 0.4996
# Epoch 7/30
# 37/37 [==============================] - 4s 104ms/step - loss: 0.3698 - auc_8: 0.8794 - mean_io_u_8: 0.4699 - val_loss: 0.9970 - val_auc_8: 0.4961 - val_mean_io_u_8: 0.4996
# Epoch 8/30
# 37/37 [==============================] - 4s 103ms/step - loss: 0.3153 - auc_8: 0.8523 - mean_io_u_8: 0.4699 - val_loss: 0.9970 - val_auc_8: 0.4964 - val_mean_io_u_8: 0.4996
# Epoch 9/30
# 37/37 [==============================] - 4s 104ms/step - loss: 0.2355 - auc_8: 0.8605 - mean_io_u_8: 0.4700 - val_loss: 0.9970 - val_auc_8: 0.4975 - val_mean_io_u_8: 0.4996
# Epoch 10/30
# 37/37 [==============================] - 4s 104ms/step - loss: 0.1826 - auc_8: 0.8450 - mean_io_u_8: 0.4702 - val_loss: 0.9970 - val_auc_8: 0.4960 - val_mean_io_u_8: 0.4996
# Epoch 11/30
# 37/37 [==============================] - 4s 103ms/step - loss: 0.1160 - auc_8: 0.8245 - mean_io_u_8: 0.4846 - val_loss: 0.9970 - val_auc_8: 0.4566 - val_mean_io_u_8: 0.4996
# Epoch 12/30
# 37/37 [==============================] - 4s 104ms/step - loss: 0.0361 - auc_8: 0.8448 - mean_io_u_8: 0.5150 - val_loss: 0.9970 - val_auc_8: 0.5162 - val_mean_io_u_8: 0.4996
# Epoch 13/30
# 37/37 [==============================] - 4s 104ms/step - loss: -0.0365 - auc_8: 0.8507 - mean_io_u_8: 0.5880 - val_loss: 0.9975 - val_auc_8: 0.4964 - val_mean_io_u_8: 0.4996
# Epoch 14/30
# 37/37 [==============================] - 4s 104ms/step - loss: -0.0485 - auc_8: 0.8131 - mean_io_u_8: 0.6114 - val_loss: 0.9984 - val_auc_8: 0.4968 - val_mean_io_u_8: 0.4996
# Epoch 15/30
# 37/37 [==============================] - 4s 103ms/step - loss: -0.1365 - auc_8: 0.8497 - mean_io_u_8: 0.6655 - val_loss: 0.9975 - val_auc_8: 0.4983 - val_mean_io_u_8: 0.4992
# Epoch 16/30
# 37/37 [==============================] - 4s 104ms/step - loss: -0.1649 - auc_8: 0.8202 - mean_io_u_8: 0.7315 - val_loss: 0.9965 - val_auc_8: 0.5731 - val_mean_io_u_8: 0.4996
# Epoch 17/30
# 37/37 [==============================] - 4s 104ms/step - loss: -0.1606 - auc_8: 0.8386 - mean_io_u_8: 0.6971 - val_loss: 0.9975 - val_auc_8: 0.4976 - val_mean_io_u_8: 0.4984
# Epoch 18/30
# 37/37 [==============================] - 4s 103ms/step - loss: -0.2023 - auc_8: 0.8440 - mean_io_u_8: 0.7374 - val_loss: 0.9935 - val_auc_8: 0.4999 - val_mean_io_u_8: 0.4996
# Epoch 19/30
# 37/37 [==============================] - 4s 104ms/step - loss: -0.2394 - auc_8: 0.8434 - mean_io_u_8: 0.7213 - val_loss: 0.8624 - val_auc_8: 0.6196 - val_mean_io_u_8: 0.5194
# Epoch 20/30
# 37/37 [==============================] - 4s 103ms/step - loss: -0.2682 - auc_8: 0.8544 - mean_io_u_8: 0.7696 - val_loss: 0.9940 - val_auc_8: 0.4990 - val_mean_io_u_8: 0.4996
# Epoch 21/30
# 37/37 [==============================] - 4s 104ms/step - loss: -0.3002 - auc_8: 0.8529 - mean_io_u_8: 0.7694 - val_loss: 0.9912 - val_auc_8: 0.4990 - val_mean_io_u_8: 0.4996
# Epoch 22/30
# 37/37 [==============================] - 4s 104ms/step - loss: -0.3109 - auc_8: 0.8438 - mean_io_u_8: 0.7679 - val_loss: 0.9975 - val_auc_8: 0.4978 - val_mean_io_u_8: 0.4986
# Epoch 23/30
# 37/37 [==============================] - 4s 105ms/step - loss: -0.3737 - auc_8: 0.8599 - mean_io_u_8: 0.7393 - val_loss: 0.7356 - val_auc_8: 0.6719 - val_mean_io_u_8: 0.5714
# Epoch 24/30
# 37/37 [==============================] - 4s 105ms/step - loss: -0.4127 - auc_8: 0.8838 - mean_io_u_8: 0.7698 - val_loss: 0.9935 - val_auc_8: 0.4990 - val_mean_io_u_8: 0.4996
# Epoch 25/30
# 37/37 [==============================] - 4s 105ms/step - loss: -0.3600 - auc_8: 0.8320 - mean_io_u_8: 0.7643 - val_loss: 0.6776 - val_auc_8: 0.9747 - val_mean_io_u_8: 0.5419
# Epoch 26/30
# 37/37 [==============================] - 4s 104ms/step - loss: -0.3707 - auc_8: 0.8547 - mean_io_u_8: 0.7788 - val_loss: 0.9090 - val_auc_8: 0.6086 - val_mean_io_u_8: 0.5109
# Epoch 27/30
# 37/37 [==============================] - 4s 104ms/step - loss: -0.4452 - auc_8: 0.8680 - mean_io_u_8: 0.8015 - val_loss: 0.9976 - val_auc_8: 0.4974 - val_mean_io_u_8: 0.4983
# Epoch 28/30
# 37/37 [==============================] - 4s 104ms/step - loss: -0.4525 - auc_8: 0.8552 - mean_io_u_8: 0.7911 - val_loss: 0.9956 - val_auc_8: 0.4985 - val_mean_io_u_8: 0.4993
# Epoch 29/30
# 37/37 [==============================] - 4s 104ms/step - loss: -0.4564 - auc_8: 0.8624 - mean_io_u_8: 0.7917 - val_loss: 0.9968 - val_auc_8: 0.4980 - val_mean_io_u_8: 0.4988
# Epoch 30/30
# 37/37 [==============================] - 4s 105ms/step - loss: -0.4817 - auc_8: 0.8728 - mean_io_u_8: 0.8131 - val_loss: 0.9946 - val_auc_8: 0.4995 - val_mean_io_u_8: 0.4992
# dice_used for training model
# Epoch 1/30
# 37/37 [==============================] - 6s 153ms/step - loss: 0.8846 - auc_9: 0.6430 - mean_io_u_9: 0.4699 - val_loss: 0.9986 - val_auc_9: 0.3231 - val_mean_io_u_9: 0.4996
# Epoch 2/30
# 37/37 [==============================] - 4s 103ms/step - loss: 0.8567 - auc_9: 0.7580 - mean_io_u_9: 0.4699 - val_loss: 0.9994 - val_auc_9: 0.3787 - val_mean_io_u_9: 0.4996
# Epoch 3/30
# 37/37 [==============================] - 4s 103ms/step - loss: 0.8410 - auc_9: 0.8192 - mean_io_u_9: 0.4699 - val_loss: 0.9988 - val_auc_9: 0.2664 - val_mean_io_u_9: 0.4996
# Epoch 4/30
# 37/37 [==============================] - 4s 103ms/step - loss: 0.8279 - auc_9: 0.8273 - mean_io_u_9: 0.4699 - val_loss: 0.9998 - val_auc_9: 0.4537 - val_mean_io_u_9: 0.4996
# Epoch 5/30
# 37/37 [==============================] - 4s 103ms/step - loss: 0.8113 - auc_9: 0.8557 - mean_io_u_9: 0.4699 - val_loss: 0.9986 - val_auc_9: 0.5066 - val_mean_io_u_9: 0.4996
# Epoch 6/30
# 37/37 [==============================] - 4s 104ms/step - loss: 0.7900 - auc_9: 0.8670 - mean_io_u_9: 0.4699 - val_loss: 0.9984 - val_auc_9: 0.6900 - val_mean_io_u_9: 0.4996
# Epoch 7/30
# 37/37 [==============================] - 4s 103ms/step - loss: 0.7593 - auc_9: 0.8860 - mean_io_u_9: 0.4699 - val_loss: 0.9985 - val_auc_9: 0.4288 - val_mean_io_u_9: 0.4996
# Epoch 8/30
# 37/37 [==============================] - 4s 104ms/step - loss: 0.7279 - auc_9: 0.8856 - mean_io_u_9: 0.4699 - val_loss: 0.9985 - val_auc_9: 0.4913 - val_mean_io_u_9: 0.4996
# Epoch 9/30
# 37/37 [==============================] - 4s 104ms/step - loss: 0.6916 - auc_9: 0.8813 - mean_io_u_9: 0.4699 - val_loss: 0.9984 - val_auc_9: 0.4925 - val_mean_io_u_9: 0.4996
# Epoch 10/30
# 37/37 [==============================] - 4s 104ms/step - loss: 0.6553 - auc_9: 0.8990 - mean_io_u_9: 0.4699 - val_loss: 0.9981 - val_auc_9: 0.4928 - val_mean_io_u_9: 0.4996
# Epoch 11/30
# 37/37 [==============================] - 4s 104ms/step - loss: 0.6274 - auc_9: 0.8930 - mean_io_u_9: 0.4699 - val_loss: 0.9977 - val_auc_9: 0.4951 - val_mean_io_u_9: 0.4996
# Epoch 12/30
# 37/37 [==============================] - 4s 104ms/step - loss: 0.5898 - auc_9: 0.8861 - mean_io_u_9: 0.4700 - val_loss: 0.9999 - val_auc_9: 0.4415 - val_mean_io_u_9: 0.4996
# Epoch 13/30
# 37/37 [==============================] - 4s 104ms/step - loss: 0.5504 - auc_9: 0.8901 - mean_io_u_9: 0.4700 - val_loss: 0.9972 - val_auc_9: 0.4964 - val_mean_io_u_9: 0.4996
# Epoch 14/30
# 37/37 [==============================] - 4s 104ms/step - loss: 0.5218 - auc_9: 0.8677 - mean_io_u_9: 0.4703 - val_loss: 0.9991 - val_auc_9: 0.4778 - val_mean_io_u_9: 0.4996
# Epoch 15/30
# 37/37 [==============================] - 4s 104ms/step - loss: 0.4710 - auc_9: 0.8762 - mean_io_u_9: 0.4819 - val_loss: 0.9531 - val_auc_9: 0.8865 - val_mean_io_u_9: 0.4996
# Epoch 16/30
# 37/37 [==============================] - 4s 104ms/step - loss: 0.4587 - auc_9: 0.8747 - mean_io_u_9: 0.4821 - val_loss: 0.9870 - val_auc_9: 0.8623 - val_mean_io_u_9: 0.4996
# Epoch 17/30
# 37/37 [==============================] - 4s 104ms/step - loss: 0.4681 - auc_9: 0.8688 - mean_io_u_9: 0.4840 - val_loss: 0.9758 - val_auc_9: 0.7331 - val_mean_io_u_9: 0.4996
# Epoch 18/30
# 37/37 [==============================] - 4s 104ms/step - loss: 0.4386 - auc_9: 0.8480 - mean_io_u_9: 0.5176 - val_loss: 0.9992 - val_auc_9: 0.4938 - val_mean_io_u_9: 0.4996
# Epoch 19/30
# 37/37 [==============================] - 4s 104ms/step - loss: 0.4028 - auc_9: 0.8514 - mean_io_u_9: 0.5318 - val_loss: 0.9851 - val_auc_9: 0.5911 - val_mean_io_u_9: 0.4996
# Epoch 20/30
# 37/37 [==============================] - 4s 104ms/step - loss: 0.3783 - auc_9: 0.8647 - mean_io_u_9: 0.5325 - val_loss: 0.9693 - val_auc_9: 0.9765 - val_mean_io_u_9: 0.4996
# Epoch 21/30
# 37/37 [==============================] - 4s 104ms/step - loss: 0.3574 - auc_9: 0.8647 - mean_io_u_9: 0.5691 - val_loss: 0.9198 - val_auc_9: 0.9915 - val_mean_io_u_9: 0.5009
# Epoch 22/30
# 37/37 [==============================] - 4s 104ms/step - loss: 0.3426 - auc_9: 0.8794 - mean_io_u_9: 0.5978 - val_loss: 0.9514 - val_auc_9: 0.7426 - val_mean_io_u_9: 0.5060
# Epoch 23/30
# 37/37 [==============================] - 4s 104ms/step - loss: 0.3484 - auc_9: 0.8569 - mean_io_u_9: 0.6089 - val_loss: 0.9608 - val_auc_9: 0.8554 - val_mean_io_u_9: 0.5129
# Epoch 24/30
# 37/37 [==============================] - 4s 104ms/step - loss: 0.3333 - auc_9: 0.8807 - mean_io_u_9: 0.5759 - val_loss: 0.9990 - val_auc_9: 0.4824 - val_mean_io_u_9: 0.4995
# Epoch 25/30
# 37/37 [==============================] - 4s 103ms/step - loss: 0.3288 - auc_9: 0.8504 - mean_io_u_9: 0.6476 - val_loss: 0.9531 - val_auc_9: 0.9861 - val_mean_io_u_9: 0.5081
# Epoch 26/30
# 37/37 [==============================] - 4s 103ms/step - loss: 0.3166 - auc_9: 0.8564 - mean_io_u_9: 0.6061 - val_loss: 0.9994 - val_auc_9: 0.4924 - val_mean_io_u_9: 0.4979
# Epoch 27/30
# 37/37 [==============================] - 4s 103ms/step - loss: 0.2861 - auc_9: 0.8664 - mean_io_u_9: 0.6269 - val_loss: 0.9992 - val_auc_9: 0.4973 - val_mean_io_u_9: 0.4984
# Epoch 28/30
# 37/37 [==============================] - 4s 104ms/step - loss: 0.3057 - auc_9: 0.8580 - mean_io_u_9: 0.6097 - val_loss: 0.9967 - val_auc_9: 0.4986 - val_mean_io_u_9: 0.4996
# Epoch 29/30
# 37/37 [==============================] - 4s 104ms/step - loss: 0.3153 - auc_9: 0.8593 - mean_io_u_9: 0.6244 - val_loss: 0.9986 - val_auc_9: 0.4983 - val_mean_io_u_9: 0.4988
# Epoch 30/30
# 37/37 [==============================] - 4s 104ms/step - loss: 0.2590 - auc_9: 0.8729 - mean_io_u_9: 0.6366 - val_loss: 0.9990 - val_auc_9: 0.4982 - val_mean_io_u_9: 0.4984
# mse_used for training model
# Epoch 1/30
# 37/37 [==============================] - 4s 98ms/step - loss: 0.2474 - mean_io_u_10: 0.4699 - val_loss: 0.2090 - val_mean_io_u_10: 0.4996
# Epoch 2/30
# 37/37 [==============================] - 3s 79ms/step - loss: 0.1994 - mean_io_u_10: 0.4699 - val_loss: 0.1711 - val_mean_io_u_10: 0.4996
# Epoch 3/30
# 37/37 [==============================] - 3s 79ms/step - loss: 0.1694 - mean_io_u_10: 0.4699 - val_loss: 0.1233 - val_mean_io_u_10: 0.4996
# Epoch 4/30
# 37/37 [==============================] - 3s 79ms/step - loss: 0.1452 - mean_io_u_10: 0.4699 - val_loss: 0.1050 - val_mean_io_u_10: 0.4996
# Epoch 5/30
# 37/37 [==============================] - 3s 79ms/step - loss: 0.1217 - mean_io_u_10: 0.4699 - val_loss: 0.0857 - val_mean_io_u_10: 0.4996
# Epoch 6/30
# 37/37 [==============================] - 3s 80ms/step - loss: 0.1092 - mean_io_u_10: 0.4699 - val_loss: 0.0823 - val_mean_io_u_10: 0.4996
# Epoch 7/30
# 37/37 [==============================] - 3s 79ms/step - loss: 0.0945 - mean_io_u_10: 0.4699 - val_loss: 0.0504 - val_mean_io_u_10: 0.4996
# Epoch 8/30
# 37/37 [==============================] - 3s 79ms/step - loss: 0.0822 - mean_io_u_10: 0.4699 - val_loss: 0.0470 - val_mean_io_u_10: 0.4996
# Epoch 9/30
# 37/37 [==============================] - 3s 79ms/step - loss: 0.0735 - mean_io_u_10: 0.4706 - val_loss: 0.0393 - val_mean_io_u_10: 0.4996
# Epoch 10/30
# 37/37 [==============================] - 3s 79ms/step - loss: 0.0645 - mean_io_u_10: 0.4702 - val_loss: 0.0286 - val_mean_io_u_10: 0.4996
# Epoch 11/30
# 37/37 [==============================] - 3s 79ms/step - loss: 0.0578 - mean_io_u_10: 0.4721 - val_loss: 0.0260 - val_mean_io_u_10: 0.4996
# Epoch 12/30
# 37/37 [==============================] - 3s 79ms/step - loss: 0.0538 - mean_io_u_10: 0.4711 - val_loss: 0.0328 - val_mean_io_u_10: 0.4996
# Epoch 13/30
# 37/37 [==============================] - 3s 79ms/step - loss: 0.0478 - mean_io_u_10: 0.4707 - val_loss: 0.0163 - val_mean_io_u_10: 0.4996
# Epoch 14/30
# 37/37 [==============================] - 3s 79ms/step - loss: 0.0442 - mean_io_u_10: 0.4709 - val_loss: 0.0141 - val_mean_io_u_10: 0.4996
# Epoch 15/30
# 37/37 [==============================] - 3s 78ms/step - loss: 0.0366 - mean_io_u_10: 0.4710 - val_loss: 0.0121 - val_mean_io_u_10: 0.4996
# Epoch 16/30
# 37/37 [==============================] - 3s 79ms/step - loss: 0.0374 - mean_io_u_10: 0.4709 - val_loss: 0.0103 - val_mean_io_u_10: 0.4996
# Epoch 17/30
# 37/37 [==============================] - 3s 79ms/step - loss: 0.0378 - mean_io_u_10: 0.4723 - val_loss: 0.0091 - val_mean_io_u_10: 0.4996
# Epoch 18/30
# 37/37 [==============================] - 3s 79ms/step - loss: 0.0342 - mean_io_u_10: 0.4805 - val_loss: 0.0089 - val_mean_io_u_10: 0.4996
# Epoch 19/30
# 37/37 [==============================] - 3s 80ms/step - loss: 0.0336 - mean_io_u_10: 0.4766 - val_loss: 0.0137 - val_mean_io_u_10: 0.4996
# Epoch 20/30
# 37/37 [==============================] - 3s 79ms/step - loss: 0.0295 - mean_io_u_10: 0.4793 - val_loss: 0.0064 - val_mean_io_u_10: 0.4996
# Epoch 21/30
# 37/37 [==============================] - 3s 79ms/step - loss: 0.0264 - mean_io_u_10: 0.4792 - val_loss: 0.0066 - val_mean_io_u_10: 0.4996
# Epoch 22/30
# 37/37 [==============================] - 3s 79ms/step - loss: 0.0257 - mean_io_u_10: 0.4802 - val_loss: 0.0061 - val_mean_io_u_10: 0.4996
# Epoch 23/30
# 37/37 [==============================] - 3s 80ms/step - loss: 0.0256 - mean_io_u_10: 0.4823 - val_loss: 0.0067 - val_mean_io_u_10: 0.4996
# Epoch 24/30
# 37/37 [==============================] - 3s 79ms/step - loss: 0.0217 - mean_io_u_10: 0.4838 - val_loss: 0.0058 - val_mean_io_u_10: 0.4996
# Epoch 25/30
# 37/37 [==============================] - 3s 79ms/step - loss: 0.0226 - mean_io_u_10: 0.4862 - val_loss: 0.0094 - val_mean_io_u_10: 0.4996
# Epoch 26/30
# 37/37 [==============================] - 3s 79ms/step - loss: 0.0244 - mean_io_u_10: 0.4884 - val_loss: 0.0067 - val_mean_io_u_10: 0.4996
# Epoch 27/30
# 37/37 [==============================] - 3s 79ms/step - loss: 0.0230 - mean_io_u_10: 0.4826 - val_loss: 0.1087 - val_mean_io_u_10: 0.4996
# Epoch 28/30
# 37/37 [==============================] - 3s 79ms/step - loss: 0.0204 - mean_io_u_10: 0.4857 - val_loss: 0.0048 - val_mean_io_u_10: 0.4996
# Epoch 29/30
# 37/37 [==============================] - 3s 80ms/step - loss: 0.0220 - mean_io_u_10: 0.4815 - val_loss: 0.0029 - val_mean_io_u_10: 0.4996
# Epoch 30/30
# 37/37 [==============================] - 3s 79ms/step - loss: 0.0181 - mean_io_u_10: 0.4943 - val_loss: 0.0027 - val_mean_io_u_10: 0.4996

# %%
from sklearn.metrics import roc_auc_score
auc_scores=[]
for i,model in enumerate(models):
  print("loss :", losses[i])
  predicted_test_label=model.predict(test_batch)  
  auc = roc_auc_score(np.round(test_label.reshape(-1)),predicted_test_label.reshape(-1))
  print("Auc-Roc score :", auc)
  auc_scores.append(auc)
print("---------------------")
print("best performing loss ", losses[np.argmax(np.array(auc_scores))] )
# Out:
# loss : trvesky
# Auc-Roc score : 0.8738335885232937
# loss : dice
# Auc-Roc score : 0.9505286366501624
# loss : mse
# Auc-Roc score : 0.8785373404885597
# ---------------------
# best performing loss  dice

# %%
predicted_test_label=models[1].predict(test_batch)
for i in range(4):
  plt.imshow(np.squeeze(predicted_test_label[i,:,:,:],axis=2),cmap='gray')
  plt.title("Predicted mask")
  plt.show()
  plt.imshow(np.squeeze(test_label[i,:,:,:],axis=2),cmap='gray')
  plt.title("ACtual mask")
  plt.show()

# %%
"""tf.keras.utils.plot_model(
    model,
    to_file="model.png",
    show_shapes=True,
    
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=24
)"""
# Out:
# 'tf.keras.utils.plot_model(\n    model,\n    to_file="model.png",\n    show_shapes=True,\n    \n    show_layer_names=True,\n    rankdir="TB",\n    expand_nested=False,\n    dpi=24\n)'

# %%
"""hist=model.fit( x = train_batch, y = train_label, batch_size = 2, epochs = 30,verbose=1,validation_split=2/76,shuffle=True)"""
# Out:
# 'hist=model.fit( x = train_batch, y = train_label, batch_size = 2, epochs = 30,verbose=1,validation_split=2/76,shuffle=True)'

# %%
i=0
for hist in history:
  plt.plot(hist.history['loss'])
  plt.title(losses[i]+'loss')
  plt.show()
  i+=1

# %%
"""predicted_test_label=models[0].predict(test_batch)"""
# Out:
# 'predicted_test_label=models[0].predict(test_batch)'

# %%
"""print(predicted_test_label[0].shape)
for i in range(4):
  plt.imshow(np.squeeze(predicted_test_label[i,:,:,:],axis=2),cmap='gray')
  plt.title("Predicted mask")
  plt.show()
  plt.imshow(np.squeeze(test_label[i,:,:,:],axis=2),cmap='gray')
  plt.title("ACtual mask")
  plt.show()"""
# Out:
# 'print(predicted_test_label[0].shape)\nfor i in range(4):\n  plt.imshow(np.squeeze(predicted_test_label[i,:,:,:],axis=2),cmap=\'gray\')\n  plt.title("Predicted mask")\n  plt.show()\n  plt.imshow(np.squeeze(test_label[i,:,:,:],axis=2),cmap=\'gray\')\n  plt.title("ACtual mask")\n  plt.show()'

# %%
predicted_train_label=models[1].predict(train_batch)

# %%
print(predicted_test_label[0].shape)
for i in range(4):
  print("Predicted")
  plt.imshow(np.squeeze(predicted_train_label[i,:,:,:],axis=2),cmap='gray')
  plt.title("predicted mask")
  plt.show()
  plt.imshow(np.squeeze(train_label[i,:,:,:],axis=2),cmap='gray')
  plt.title("actual mask")
  plt.show()
# Out:
# (512, 512, 1)
# Predicted
# Predicted
# Predicted
# Predicted

# %%
"""#serialize and save model 
# serialize model to JSON
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model.h5")
print("Saved model to disk")"""
# Out:
# '#serialize and save model \n# serialize model to JSON\nmodel_json = model.to_json()\nwith open("model.json", "w") as json_file:\n    json_file.write(model_json)\n# serialize weights to HDF5\nmodel.save_weights("model.h5")\nprint("Saved model to disk")'

# %%
"""from keras.models import model_from_json

# load json and create model
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)

# load weights into new model
loaded_model.load_weights("model.h5")
print("Loaded model from disk")

# evaluate loaded model on test data
loaded_model.compile()
print("Model loaded")"""
# Out:
# 'from keras.models import model_from_json\n\n# load json and create model\njson_file = open(\'model.json\', \'r\')\nloaded_model_json = json_file.read()\njson_file.close()\nloaded_model = model_from_json(loaded_model_json)\n\n# load weights into new model\nloaded_model.load_weights("model.h5")\nprint("Loaded model from disk")\n\n# evaluate loaded model on test data\nloaded_model.compile()\nprint("Model loaded")'

# %%
"""pred_test_label_loaded_mod=loaded_model.predict(test_batch)"""
# Out:
# 'pred_test_label_loaded_mod=loaded_model.predict(test_batch)'

# %%
"""from sklearn.metrics import balanced_accuracy_score
balanced_accuracy_score(np.round(test_label.reshape(-1)),np.round(pred_test_label_loaded_mod.reshape(-1)))"""
# Out:
# 'from sklearn.metrics import balanced_accuracy_score\nbalanced_accuracy_score(np.round(test_label.reshape(-1)),np.round(pred_test_label_loaded_mod.reshape(-1)))'

# %% [markdown]
# # test set scores

# %%
"""testy, yhat_classes=(np.round(test_label.reshape(-1)),np.round(pred_test_label_loaded_mod.reshape(-1)))"""
# Out:
# 'testy, yhat_classes=(np.round(test_label.reshape(-1)),np.round(pred_test_label_loaded_mod.reshape(-1)))'

# %%
"""from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

accuracy = accuracy_score(testy, yhat_classes)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(testy, yhat_classes)
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(testy, yhat_classes)
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(testy, yhat_classes)
print('F1 score: %f' % f1)"""
# Out:
# "from sklearn.metrics import accuracy_score\nfrom sklearn.metrics import precision_score\nfrom sklearn.metrics import recall_score\nfrom sklearn.metrics import f1_score\n\naccuracy = accuracy_score(testy, yhat_classes)\nprint('Accuracy: %f' % accuracy)\n# precision tp / (tp + fp)\nprecision = precision_score(testy, yhat_classes)\nprint('Precision: %f' % precision)\n# recall: tp / (tp + fn)\nrecall = recall_score(testy, yhat_classes)\nprint('Recall: %f' % recall)\n# f1: 2 tp / (2 tp + fp + fn)\nf1 = f1_score(testy, yhat_classes)\nprint('F1 score: %f' % f1)"

# %% [markdown]
# # train set scores

# %%
"""testy, yhat_classes=(np.round(train_label.reshape(-1)),np.round(predicted_train_label.reshape(-1)))"""
# Out:
# 'testy, yhat_classes=(np.round(train_label.reshape(-1)),np.round(predicted_train_label.reshape(-1)))'

# %%
"""accuracy = accuracy_score(testy, yhat_classes)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(testy, yhat_classes)
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(testy, yhat_classes)
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(testy, yhat_classes)
print('F1 score: %f' % f1)"""
# Out:
# "accuracy = accuracy_score(testy, yhat_classes)\nprint('Accuracy: %f' % accuracy)\n# precision tp / (tp + fp)\nprecision = precision_score(testy, yhat_classes)\nprint('Precision: %f' % precision)\n# recall: tp / (tp + fn)\nrecall = recall_score(testy, yhat_classes)\nprint('Recall: %f' % recall)\n# f1: 2 tp / (2 tp + fp + fn)\nf1 = f1_score(testy, yhat_classes)\nprint('F1 score: %f' % f1)"

# %% [markdown]
# # roc value

# %%
"""# ROC AUC
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(np.round(train_label.reshape(-1)),predicted_train_label.reshape(-1))
print('ROC AUC: %f' % auc)"""
# Out:
# "# ROC AUC\nfrom sklearn.metrics import roc_auc_score\nauc = roc_auc_score(np.round(train_label.reshape(-1)),predicted_train_label.reshape(-1))\nprint('ROC AUC: %f' % auc)"
